# %% [markdown]
# # Data visualization
# It starts with the problem statement and we seek answer by a graph or visualization.  Here we will explore scatter plot.  The problem statement is wage in city of Seatel dependend on age and gender?
# ## Scatterplot
# Scatterplot is providing information on interdependency of data, it shows relationship linear, directional and strength.  It also helps to identify outliars.
#
# We will follow below steps and the data set - Seatel wage comparision to understand scatterplot further.
# - Load the library
# - Load the data and explore it
# - Create a scatterplot
# - Enhance the plot by
#     - Removing some unnneeded values
#     - Adding title
#     - Resizing the plot
#     - Giving labels to the x axis and the y axis

# %%
import pandas as pd
import matplotlib as plt
import numpy as np

df = pd.read_csv('./City_of_Seattle_Wages__Comparison_by_Gender_-_Average_Hourly_Wage_by_Age.csv')
print(df.info())
#print(df.head())
#print(df.describe())
#df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   AGE RANGE                      13 non-null     object
#  1   Average of FEMALE HOURLY RATE  13 non-null     float64
#  2   Count of FEMALE EMPLID         13 non-null     int64
#  3   Average of MALE HOURLY RATE    13 non-null     float64
#  4   Count of MALE EMPLID           13 non-null     int64
#  5   Total Average of HOURLY RATE   13 non-null     float64
#  6   Total Count of EMPLID          13 non-null     int64
#  7   Female to male % rate          13 non-null     float64
# dtypes: float64(4), int64(3), object(1)
# memory usage: 964.0+ bytes
# None

# %%
# prepare the chart
import pandas as pd
import matplotlib.pyplot as plt

#fetch data
df = pd.read_csv('./City_of_Seattle_Wages__Comparison_by_Gender_-_Average_Hourly_Wage_by_Age.csv')
#df.info()
#df.head()
#df.describe()

#prepare plot
plt.figure(figsize = (12,6))
df1 = df['AGE RANGE']
df2 = df['Total Average of HOURLY RATE']
plt.scatter(df['AGE RANGE'],df['Total Average of HOURLY RATE'])
#plt.scatter(df1, df2) 
plt.xlabel('AGE RANGE')
plt.ylabel('Total Average of HOURLY RATE')
plt.title('Interdependence between Age Range and Total Average of HOURLY RATE')
# Out:
# Text(0.5, 1.0, 'Interdependence between Age Range and Total Average of HOURLY RATE')

# %%
# improve the graph
import pandas as pd
import matplotlib.pyplot as plt

#load data
df  =   df = pd.read_csv('./City_of_Seattle_Wages__Comparison_by_Gender_-_Average_Hourly_Wage_by_Age.csv')

#plot graph
plt.figure(figsize=(12,6))
df1 =   df['AGE RANGE']
df2 =   df['Total Average of HOURLY RATE']
plt.scatter(df1[:-2],df2[:-2])  #if we use -1, -2 that way we can remove x axis value from the right hand side
plt.xlabel  =   'AGE RANGE'
plt.ylabel  =   'Total Average of HOURLY RATE'
plt.title   =   'Interdependence between Age Range and Total Average of HOURLY RATE'

# %% [markdown]
# Here is an illustration for relationships
# ![Scatter Plot Dependencies](scatterplot-interdependency.png)
# - Quadrant 1: Linear Positive Dependency
# - As one variable increases, the other also increases.
# - 📈 Example: Hours studied vs. exam scores — more study leads to better results.
# - Quadrant 2: Linear Negative Dependency
# - As one variable increases, the other decreases.
# - 📉 Example: Age of a car vs. resale value — older cars tend to be worth less.
# - Quadrant 3: Curvilinear (Nonlinear) Dependency
# - The relationship follows a curve rather than a straight line.
# - 🧠 Example: Stress vs. performance — moderate stress improves performance, but too much or too little reduces it.
# - Quadrant 4: No Clear Dependency (Scattered)
# - No obvious pattern or correlation between the variables.
# - 🎲 Example: Shoe size vs. IQ — unrelated variables with random scatter.
#
# These patterns help students and analysts visually assess how two variables relate, which is essential in fields like education, economics, psychology, and data science. Let me know if you’d like to add visuals or real datasets to reinforce these concepts!

# %%
# Multiple scatter plots in same graph
import pandas as pd
import matplotlib.pyplot as plt

#import data
df  =   pd.read_excel('./MAINECOUNTIESPARTIES.xlsx')
#print(df.info())
print(df.head())
#print(df.describe())

#plot data
plt.figure(figsize=(18,6))
plt.scatter(df['counties'],df['Democratic'],c=['b'],label='Democrate')
plt.scatter(df['counties'],df['Republican'],marker='^',c=['r'],label='Republican')
plt.legend()
plt.xlabel('Counties')
plt.ylabel('Republican red and Democratic blue')
plt.title('Maine Counties and Parties')
# Out:
#        counties  Republican  Democratic
# 0  Androscoggin       28189       22975
# 1     Aroostook       19419       13377
# 2    Cumberland       57697      102935
# 3      Franklin        7900        7001
# 4       Hancock       13682       16107
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 16
#      14 plt.scatter(df['counties'],df['Republican'],marker='^',c=['r'],label='Republican')
#      15 plt.legend()
# ---> 16 plt.xlabel('Counties')
#      17 plt.ylabel('Republican red and Democratic blue')
#      18 plt.title('Maine Counties and Parties')
#
# TypeError: 'str' object is not callable

# %% [markdown]
# Outcome: Cumberland has highest voters for Democrate and Penobscot has highest voters for Republican.  Hence Cumberland is a choice for rally for Democrate and Penobscot is a choice for rally for Republican.
